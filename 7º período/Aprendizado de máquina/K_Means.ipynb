# %% [markdown]
# # Tarefa 1: Assistir ao documentário Coded Bias, disponível na Netflix, e fazer um resumo.
#
# No documentário, é apresentado a pesquisadora Joy Buolamwini que descobriu casos de preconceitos raciais e de gênero incorporados em softwares de reconhecimento facial. Buolamwini descobriu o caso na faculdade, quando desenvolveu um projeto de reconhecimento facial que deveria sobrepor o seu rosto com alguma imagem (como emoji). No entanto, o seu projeto não funcionava corretamente e ao investigar o problema, percebeu que só conseguia executá-lo se estivesse utilizando uma máscara branca e descobriu assim, que a questão era o preconceito existente no código que não reconhecia o seu tom de pele.
#
# Posteriormente o documentário apresenta a trajetória de Buolamwini investigando mais sobre o assunto e conhecendo alguns poucos outros autores sobre o assunto, sua maioria mulheres, que se preocupam com os impactos que esses preconceitos podem gerar na sociedade incluindo prisões incorretas e acusações injustas.
# Entre os diversos exemplos que foi citado, existe o sistema de avaliação de professores, que causou inúmeras demissões devido as avaliações incorretas geradas por algoritmos. Comenta também do caso de uma jovem afrodescendente que necessita usar tornezeleira por ser considera um risco em potencial. Outro exemplo prejudicial, é o de algoritmos para avaliação de currículos para contratação que reprovava a maioria dos currículos femininos.
#
# Exemplificando casos mais extremos, foi citado o Sistema de Crédito Social chinês que utiliza o sistema de reconhecimento facial para vigilância em massa da população. Esse exemplo levanta pontos importantes sobre os impactos na privacidade que o uso de tecnologias podem causar, ao limitar a liberdade de expressão e atentar contra os direitos humanos.
#
# Outro país que tem sido criticado pelo uso indevido de reconhecimento facial de maneira invasiva é o Reinio Unido, que utiliza o sistema para monitoramento na em locais públicos. Esse exemplo foi apresentado como uma caso de invasão de privacidade, exempleficando quando um homem é abordado e multado pela polícia por cobrir o seu rosto como forma de protesto a uso do sistema e o caso de um jovem adolescente negro que foi abordado pela polícia devido um erro do sistema de reconhecimento facial.
#
# Ao falar sobre as formas de protestos contra o assunto, o documentário apresentou a Liga da Justiça Algorítmica, um grupo de especialistas e ativistas que trabalham em prol do uso ético e justo das tecnologias. Onde esse grupo seria responsável por avaliar e monitorar o desenvolvimento de tecnologias como meio de garantir que eles não possuiriam a discriminação ou injustiças existentes por parte dos programadores. Apresentou também a Lei de Privacidade do Consumidor da Califórnia (CCPA) aprovada em 2018 e em vigor desde 2020, estabelecendo novos direitos de privacidade para os consumidores californianos. Os direitos garantidos pela lei, incluem o direito de saber quais dados são coletados, impedir venda a terceiros dos dados e requisitar a exclusão de seus dados. Porém, o documentário destaca que a legislação atual não é abrangente e rigorosa o bastante para regular o uso das tecnologias baseadas em IAs, o que impede que elas sejam desenvolvidas e usadas de maneira ética e equitativa.
#
# Em última ponto, o documentário mostra o quanto os desenvolvedores influenciam o código, ao demonstrar que a taxa de precisão dos algoritmos de reconhecimento facial tendem a cair ao considerar sexo e cor de pele e como a falta de diversidade nos dados usados para o desenvolvimento e treinamento dos algoritmos pode levar a resultados injustos e discriminatórios. Portanto, destaca como deve-se ter uma preocupação para desenvolvimento de novas tecnologias de forma a torna-lás mais inclusivas e para tal, deve-se começar preocupando desde o levantamento de dados.

# %% [markdown]
# # Tarefa 2: Ler os slides sobre o método de aprendizado de máquina não supervisionado conhecido com K-Means e fazer os exercícios disponíveis nele.
#
# Implemente o exemplo.
#
# Implemente sua versão do k-means e aplique aos dados do
# exemplo com k = 2. O resultado foi o mesmo?

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
x = [4, 5, 10, 4, 3, 11, 14, 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

plt.scatter(x, y)
plt.show()

data = list(zip(x, y))
inertias = []

for i in range(1,11):
  kmeans = KMeans(n_clusters=i, n_init= 10)
  kmeans.fit(data)
  inertias.append(kmeans.inertia_)

plt.plot(range(1,11), inertias, marker='o')
plt.title('Método do Cotovelo')
plt.xlabel('Número de clusters')
plt.ylabel('Inércia')
plt.show()

# %%
kmeans = KMeans (n_clusters=2, n_init = 'auto')
kmeans.fit(data)

plt.scatter(x, y, c=kmeans.labels_)
plt.show()
