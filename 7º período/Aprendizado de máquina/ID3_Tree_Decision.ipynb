# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import copy

# %%
dataset = pd.read_csv('data.csv')
X = dataset.iloc[:, :].values
print(X)
attribute = ['Age', 'Experience', 'Rank', 'Nationality']
# Out:
# [[36 10 9 'UK' 'NO']
#  [42 12 4 'USA' 'NO']
#  [23 4 6 'N' 'NO']
#  [52 4 4 'USA' 'NO']
#  [43 21 8 'USA' 'YES']
#  [44 14 5 'UK' 'NO']
#  [66 3 7 'N' 'YES']
#  [35 14 9 'UK' 'YES']
#  [52 13 7 'N' 'YES']
#  [35 5 9 'N' 'YES']
#  [24 3 5 'USA' 'NO']
#  [18 3 7 'UK' 'YES']
#  [45 9 9 'UK' 'YES']]

# %%
class Node(object):
    def __init__(self):
        self.value = None
        self.decision = None
        self.childs = None


def findEntropy(data, rows):
    yes = 0
    no = 0
    ans = -1
    idx = len(data[0]) - 1
    print("Resultado Go:", data[0][idx])
    entropy = 0
    for i in rows:
        if data[i][idx] == 'YES':
            yes = yes + 1
        else:
            no = no + 1
    x = yes/(yes+no)
    y = no/(yes+no)
    if x != 0 and y != 0:
        entropy = -1 * (x*math.log2(x) + y*math.log2(y))
    if x == 1:
        ans = 1
    if y == 1:
        ans = 0
    print("Valor entropia: ",entropy)
    return entropy, ans


def findMaxGain(data, rows, columns):
    maxGain = 0
    retidx = -1
    entropy, ans = findEntropy(data, rows)
    if entropy == 0:
        return maxGain, retidx, ans

    for j in columns:
        mydict = {}
        idx = j
        for i in rows:
            key = data[i][idx]
            if key not in mydict:
                mydict[key] = 1
            else:
                mydict[key] = mydict[key] + 1
        gain = entropy

        print(mydict)
        for key in mydict:
            yes = 0
            no = 0
            for k in rows:
                if data[k][j] == key:
                    if data[k][-1] == 'YES':
                        yes = yes + 1
                    else:
                        no = no + 1
            print("Quantidade de sim e não:", yes, no)
            x = yes/(yes+no)
            y = no/(yes+no)
            print(x, y)
            if x != 0 and y != 0:
                gain += (mydict[key] * (x*math.log2(x) + y*math.log2(y)))/14
        print("Valor de ganho:", gain)
        if gain > maxGain:
            
            maxGain = gain
            retidx = j

    return maxGain, retidx, ans


def buildTree(data, rows, columns):

    maxGain, idx, ans = findMaxGain(X, rows, columns)
    root = Node()
    root.childs = []
    print(maxGain)
    if maxGain == 0:
        if ans == 1:
            root.value = 'YES'
        else:
            root.value = 'NO'
        return root

    root.value = attribute[idx]
    mydict = {}
    for i in rows:
        key = data[i][idx]
        if key not in mydict:
            mydict[key] = 1
        else:
            mydict[key] += 1

    newcolumns = copy.deepcopy(columns)
    newcolumns.remove(idx)
    for key in mydict:
        newrows = []
        for i in rows:
            if data[i][idx] == key:
                newrows.append(i)
        # print(newrows)
        temp = buildTree(data, newrows, newcolumns)
        temp.decision = key
        root.childs.append(temp)
    return root


def traverse(root):
    print(root.decision)
    print(root.value)

    n = len(root.childs)
    if n > 0:
        for i in range(0, n):
            traverse(root.childs[i])


def calculate():
    rows = [i for i in range(0, 13)]
    columns = [i for i in range(0, 4)]
    root = buildTree(X, rows, columns)
    root.decision = 'Raiz'
    traverse(root)


calculate()
# Out:
# Resultado Go: NO
# Valor entropia:  0.9957274520849255
# {36: 1, 42: 1, 23: 1, 52: 2, 43: 1, 44: 1, 66: 1, 35: 2, 24: 1, 18: 1, 45: 1}
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 1 1
# 0.5 0.5
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Quantidade de sim e não: 2 0
# 1.0 0.0
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Valor de ganho: 0.8528703092277827
# {10: 1, 12: 1, 4: 2, 21: 1, 14: 2, 3: 3, 13: 1, 5: 1, 9: 1}
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 0 2
# 0.0 1.0
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Quantidade de sim e não: 1 1
# 0.5 0.5
# Quantidade de sim e não: 2 1
# 0.6666666666666666 0.3333333333333333
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Valor de ganho: 0.6560926305018207
# {9: 4, 4: 2, 6: 1, 8: 1, 5: 2, 7: 3}
# Quantidade de sim e não: 3 1
# 0.75 0.25
# Quantidade de sim e não: 0 2
# 0.0 1.0
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Quantidade de sim e não: 0 2
# 0.0 1.0
# Quantidade de sim e não: 3 0
# 1.0 0.0
# Valor de ganho: 0.763933702239459
# {'UK': 5, 'USA': 4, 'N': 4}
# Quantidade de sim e não: 3 2
# 0.6 0.4
# Quantidade de sim e não: 1 3
# 0.25 0.75
# Quantidade de sim e não: 3 1
# 0.75 0.25
# Valor de ganho: 0.18537188294589657
# 0.8528703092277827
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  1.0
# {4: 1, 13: 1}
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Valor de ganho: 1.0
# {4: 1, 7: 1}
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Valor de ganho: 1.0
# {'USA': 1, 'N': 1}
# Quantidade de sim e não: 0 1
# 0.0 1.0
# Quantidade de sim e não: 1 0
# 1.0 0.0
# Valor de ganho: 1.0
# 1.0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Resultado Go: NO
# Valor entropia:  0
# 0
# Raiz
# Age
# 36
# NO
# 42
# NO
# 23
# NO
# 52
# Experience
# 4
# NO
# 13
# YES
# 43
# YES
# 44
# NO
# 66
# YES
# 35
# YES
# 24
# NO
# 18
# YES
# 45
# YES
